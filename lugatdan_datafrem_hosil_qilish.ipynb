# %% [markdown]
# <a href="https://colab.research.google.com/github/shoxruxmamitov/pandas-kutubxonasi/blob/main/lugatdan_datafrem_hosil_qilish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
from pandas import Series, DataFrame

# %%
aholi1 = {
    'Uzbekistan': {2021:33.59, 2022:35.27, 2023:36.80, 2024:37.54, 2025:38},
    'Kazakistan': {2021:19.74, 2022:20.03, 2023:20.33, 2024:20.59, 2025:20.96}
      } #aholi1 oddi lugat hosil qilamiz

# %%
aholi_soni = DataFrame(aholi1)
aholi_soni  # jadval korinishiga otkizamiz
# Out:
#       Uzbekistan  Kazakistan
# 2021       33.59       19.74
# 2022       35.27       20.03
# 2023       36.80       20.33
# 2024       37.54       20.59
# 2025       38.00       20.96

# %%
aholi_soni.index.name='yil' # index ga nom berib oldik

# %%
aholi_soni
# Out:
#       Uzbekistan  Kazakistan
# yil
# 2021       33.59       19.74
# 2022       35.27       20.03
# 2023       36.80       20.33
# 2024       37.54       20.59
# 2025       38.00       20.96

# %%
aholi_soni = pd.DataFrame(aholi1, index=[2023, 2021])
aholi_soni # bizga kerakli malumotarni chiqarib oldik
# Out:
#       Uzbekistan  Kazakistan
# 2023       36.80       20.33
# 2021       33.59       19.74

# %%
aholi_soni.T # transforme qilib oldik
# Out:
#              2023   2021
# Uzbekistan  36.80  33.59
# Kazakistan  20.33  19.74

# %%
arr = aholi_soni.values
arr #array ga otqizib ollik
# Out:
# array([[36.8 , 20.33],
#        [33.59, 19.74]])

# %%
type(arr)
# Out:
# numpy.ndarray
