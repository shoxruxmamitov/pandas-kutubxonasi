# %% [markdown]
# <a href="https://colab.research.google.com/github/shoxruxmamitov/pandas-kutubxonasi/blob/main/data_frem_va_ustunlari.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
from pandas import Series, DataFrame

# %%
OLTIN = {
    'Kun': ['Пн', 'Вт', 'Ср', 'Чт', 'Пт', 'Сб', 'Вс'],
    'Pips': [6861, 5628, 5818, 6893, 6704, 0, 0],
    'Foiz': ['1.45%', '1.22%', '1.29%', '1.56%', '1.48%', '0%', '0%' ]
}
OLTIN # oddi lugat hosil qilib olamiz
# Out:
# {'Kun': ['Пн', 'Вт', 'Ср', 'Чт', 'Пт', 'Сб', 'Вс'],
#  'Pips': [6861, 5628, 5818, 6893, 6704, 0, 0],
#  'Foiz': ['1.45%', '1.22%', '1.29%', '1.56%', '1.48%', '0%', '0%']}

# %%
XAUUSD = DataFrame(OLTIN)
XAUUSD #jadval hosil qilib oldik
# Out:
#   Kun  Pips   Foiz
# 0  Пн  6861  1.45%
# 1  Вт  5628  1.22%
# 2  Ср  5818  1.29%
# 3  Чт  6893  1.56%
# 4  Пт  6704  1.48%
# 5  Сб     0     0%
# 6  Вс     0     0%

# %%
XAUUSD.shape #qatorini bilib oldik
# Out:
# (7, 3)

# %%
XAUUSD.columns = ['день', 'пункт', 'процент',]
XAUUSD # index nomini yani kun, pips, foiz index nomlarini den punkt prosent ga almashtirib oldik
# Out:
#   день  пункт процент
# 0   Пн   6861   1.45%
# 1   Вт   5628   1.22%
# 2   Ср   5818   1.29%
# 3   Чт   6893   1.56%
# 4   Пт   6704   1.48%
# 5   Сб      0      0%
# 6   Вс      0      0%

# %%
XAUUSD.shape # qatorini olchab oldik
# Out:
# (7, 3)

# %%
XAUUSD.columns = ['день', 'пункт', 'процент',]
XAUUSD.index = [1, 2, 3, 4, 5, 6, 7]
XAUUSD   # indexga nom berdik 0 dan emas 1 dan boshlandi chalgimaslik uchun eslatdim
# Out:
#   день  пункт процент
# 1   Пн   6861   1.45%
# 2   Вт   5628   1.22%
# 3   Ср   5818   1.29%
# 4   Чт   6893   1.56%
# 5   Пт   6704   1.48%
# 6   Сб      0      0%
# 7   Вс      0      0%

# %%
XAUUSD['день'] # den index malumotlarini chaqirib oldik
# Out:
# 1    Пн
# 2    Вт
# 3    Ср
# 4    Чт
# 5    Пт
# 6    Сб
# 7    Вс
# Name: день, dtype: object

# %%
XAUUSD['пункт'] # punkt index malumotlarini chaqirib oldik
# Out:
# 1    6861
# 2    5628
# 3    5818
# 4    6893
# 5    6704
# 6       0
# 7       0
# Name: пункт, dtype: int64

# %%
kunlar = XAUUSD['процент']
kunlar #protsent index malumotlarini chaqirib oldik
# Out:
# 1    1.45%
# 2    1.22%
# 3    1.29%
# 4    1.56%
# 5    1.48%
# 6       0%
# 7       0%
# Name: процент, dtype: object

# %%
#XAUUSD.процент = 0  # protsent malumotlarini hammasini 0 ga ozgartirdik

# %%
#val = XAUUSD.Series([812, 712, 567], index = [2, 4, 6])
#XAUUSD.процент = val
   # protsent malumotlar qoshib va uni 2 , 4, va 6 chi qatorlarga malumot sifatida qoshib qodim

# %%
#val = [126, 231, 312, 567, 766, 912, 212, 777]
#XAUUSD.процент = val
     # protsent index ga malumotlar qoshib qodik

# %%
XAUUSD['1.2%+']=XAUUSD.процент>='1.2%'
XAUUSD # 1.2% index qoshib oldim va 1.2% dan katta bolhan malumotlarni True kichik bolsa False qatarishini soradim
# Out:
#   день  пункт процент  1.2%+
# 1   Пн   6861   1.45%   True
# 2   Вт   5628   1.22%   True
# 3   Ср   5818   1.29%   True
# 4   Чт   6893   1.56%   True
# 5   Пт   6704   1.48%   True
# 6   Сб      0      0%  False
# 7   Вс      0      0%  False

# %%
#del XAUUSD['1.2%']
#XAUUSD # 1.2% qoshgan index ni ochirish uchun del funksiasidan fodalandim

# %%
XAUUSD # biz hosil qilga jadval va unga ishlov berganimiz
# Out:
#   день  пункт процент  1.2%+
# 1   Пн   6861   1.45%   True
# 2   Вт   5628   1.22%   True
# 3   Ср   5818   1.29%   True
# 4   Чт   6893   1.56%   True
# 5   Пт   6704   1.48%   True
# 6   Сб      0      0%  False
# 7   Вс      0      0%  False
