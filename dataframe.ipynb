# %% [markdown]
# <a href="https://colab.research.google.com/github/shoxruxmamitov/pandas-kutubxonasi/blob/main/dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
from pandas import Series, DataFrame

# %%
norma ={
    'kun': ['dushanba', 'seshanba', 'chorshanba', 'payshanba', 'juma', 'shanba', 'yakshanba' ],
    'ishchi': ['Bobur', 'Muhammad', 'Bosithon', 'O\'rinbosar', 'Shoxrux', 'Laziz', 'O\'ktam'],
    'soati': [ 7.5, 5.8, 8.1, 4.6, 8.0, 5.9, 3.7],
    'obshi chast': [25, 31, 28, 40, 19, 28, 42 ]
}
norma   #norma degan oddi lugat hosil qilib olamiz
# Out:
# {'kun': ['dushanba',
#   'seshanba',
#   'chorshanba',
#   'payshanba',
#   'juma',
#   'shanba',
#   'yakshanba'],
#  'ishchi': ['Bobur',
#   'Muhammad',
#   'Bosithon',
#   "O'rinbosar",
#   'Shoxrux',
#   'Laziz',
#   "O'ktam"],
#  'soati': [7.5, 5.8, 8.1, 4.6, 8.0, 5.9, 3.7],
#  'obshi chast': [25, 31, 28, 40, 19, 28, 42]}

# %%
normachast = pd.DataFrame(norma)
normachast # va uni dataframe orqali jadval korinishiga kelitirib olamiz
# Out:
#           kun      ishchi  soati  obshi chast
# 0    dushanba       Bobur    7.5           25
# 1    seshanba    Muhammad    5.8           31
# 2  chorshanba    Bosithon    8.1           28
# 3   payshanba  O'rinbosar    4.6           40
# 4        juma     Shoxrux    8.0           19
# 5      shanba       Laziz    5.9           28
# 6   yakshanba      O'ktam    3.7           42

# %%
normachast.head(3) # 0 dan 3 gacha bolgan jadvalni head orqali chiqarib oldik
# Out:
#           kun    ishchi  soati  obshi chast
# 0    dushanba     Bobur    7.5           25
# 1    seshanba  Muhammad    5.8           31
# 2  chorshanba  Bosithon    8.1           28

# %%
normachast.tail(3) # va qolgan 3 ta jadvalni tail orqali chiqarib oldik
# Out:
#          kun   ishchi  soati  obshi chast
# 4       juma  Shoxrux    8.0           19
# 5     shanba    Laziz    5.9           28
# 6  yakshanba   O'ktam    3.7           42
