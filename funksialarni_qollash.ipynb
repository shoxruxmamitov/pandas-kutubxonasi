# %% [markdown]
# <a href="https://colab.research.google.com/github/shoxruxmamitov/pandas-kutubxonasi/blob/main/funksialarni_qollash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
tir = pd.DataFrame(np.random.randn(3, 4), index=list('opq'), columns=['Olma', 'Anjir', 'Gilos', 'Banan'])

# %%
tir
# Out:
#        Olma     Anjir     Gilos     Banan
# o -1.245634 -0.844064  0.793914  1.357109
# p  0.253739  0.677162 -0.314649  1.444946
# q -0.492528 -1.112626  1.120510 -0.294685

# %%
np.abs(tir)
# Out:
#        Olma     Anjir     Gilos     Banan
# o  1.245634  0.844064  0.793914  1.357109
# p  0.253739  0.677162  0.314649  1.444946
# q  0.492528  1.112626  1.120510  0.294685

# %%
np.round(tir)
# Out:
#    Olma  Anjir  Gilos  Banan
# o  -1.0   -1.0    1.0    1.0
# p   0.0    1.0   -0.0    1.0
# q  -0.0   -1.0    1.0   -0.0

# %%
tir
# Out:
#        Olma     Anjir     Gilos     Banan
# o -1.245634 -0.844064  0.793914  1.357109
# p  0.253739  0.677162 -0.314649  1.444946
# q -0.492528 -1.112626  1.120510 -0.294685

# %%
tir.mean() # olma, anjir, gilos, banan uchun ortacha qimat
# Out:
# Olma    -0.494808
# Anjir   -0.426509
# Gilos    0.533258
# Banan    0.835790
# dtype: float64

# %%
tir.mean(axis = 1) # o , p , q uchun   prtacha qimat
# Out:
# o    0.015331
# p    0.515300
# q   -0.194832
# dtype: float64

# %%
tir.apply(np.abs)
# Out:
#        Olma     Anjir     Gilos     Banan
# o  1.245634  0.844064  0.793914  1.357109
# p  0.253739  0.677162  0.314649  1.444946
# q  0.492528  1.112626  1.120510  0.294685

# %%
tir.apply(sum)
# Out:
# Olma    -1.484423
# Anjir   -1.279528
# Gilos    1.599775
# Banan    2.507370
# dtype: float64

# %%
tir.apply(sum, axis = 1)
# Out:
# o    0.061325
# p    2.061199
# q   -0.779329
# dtype: float64

# %%
s = lambda x: x.max() - x.min()

# %%
tir.apply(s)
# Out:
# Olma     1.499373
# Anjir    1.789787
# Gilos    1.435159
# Banan    1.739632
# dtype: float64

# %%
def foo(x):
  return pd.Series([x.min(), x.max()], index=['min', 'max'])

# %%
tir.apply(foo)
# Out:
#          Olma     Anjir     Gilos     Banan
# min -1.245634 -1.112626 -0.314649 -0.294685
# max  0.253739  0.677162  1.120510  1.444946

# %%
tir
# Out:
#        Olma     Anjir     Gilos     Banan
# o -1.245634 -0.844064  0.793914  1.357109
# p  0.253739  0.677162 -0.314649  1.444946
# q -0.492528 -1.112626  1.120510 -0.294685

# %%
tir.applymap()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-102135579.py in <cell line: 0>()
# ----> 1 tir.applymap()
#
# TypeError: DataFrame.applymap() missing 1 required positional argument: 'func'

# %%
kr = pd.DataFrame(np.arange(1, 13).reshape(3,4), index=list('hkl'), columns=['Karam', 'Pamidor', 'Juxori', 'Pamidor'])

# %%
kr
# Out:
#    Karam  Pamidor  Juxori  Pamidor
# h      1        2       3        4
# k      5        6       7        8
# l      9       10      11       12

# %%
kr.applymap(lambda x: x**2)
# Out:
# /tmp/ipython-input-783831359.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   kr.applymap(lambda x: x**2)
#    Karam  Pamidor  Juxori  Pamidor
# h      1        4       9       16
# k     25       36      49       64
# l     81      100     121      144

# %%
kr.applymap(lambda x: x*x)
# Out:
# /tmp/ipython-input-318449898.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   kr.applymap(lambda x: x*x)
#    Karam  Pamidor  Juxori  Pamidor
# h      1        4       9       16
# k     25       36      49       64
# l     81      100     121      144
