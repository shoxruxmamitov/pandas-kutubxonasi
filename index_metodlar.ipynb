# %% [markdown]
# <a href="https://colab.research.google.com/github/shoxruxmamitov/pandas-kutubxonasi/blob/main/index_metodlar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
from pandas import Series, DataFrame

# %%
muzic_nom = {'Shoxruxxon':'parizod', "G'aybulla Tursunov":'quralay', 'Shahlo Ahmedova':'avayla', 'Bojalar':'anhor', 'Ismail':'ifori kelsin'}
sanasi = {'Shoxruxxon':2005, "G'aybulla Tursunov":2025, "Shahlo Ahmedova":2017, 'Bojalar':2007, 'Ismail':2025}

muzic1 = {
    'muzic_name' : muzic_nom,
    'nashr_sanasi' : sanasi
}

# %%
muzic = pd.DataFrame(muzic1)

# %%
muzic
# Out:
#                       muzic_name  nashr_sanasi
# Shoxruxxon               parizod          2005
# G'aybulla Tursunov       quralay          2025
# Shahlo Ahmedova           avayla          2017
# Bojalar                    anhor          2007
# Ismail              ifori kelsin          2025

# %%
muzic.index.name='ijrochi'

# %%
muzic
# Out:
#                       muzic_name  nashr_sanasi
# ijrochi
# Shoxruxxon               parizod          2005
# G'aybulla Tursunov       quralay          2025
# Shahlo Ahmedova           avayla          2017
# Bojalar                    anhor          2007
# Ismail              ifori kelsin          2025

# %%
muzic.index
# Out:
# Index(['Shoxruxxon', 'G'aybulla Tursunov', 'Shahlo Ahmedova', 'Bojalar',
#        'Ismail'],
#       dtype='object', name='ijrochi')

# %%
arr = ['Shoxruxxon', 'G\'aybulla Tursunov', 'Shahlo Ahmedova', 'Bojalar', 'Ismail']
arr
# Out:
# ['Shoxruxxon', "G'aybulla Tursunov", 'Shahlo Ahmedova', 'Bojalar', 'Ismail']

# %%
arr[2]
# Out:
# 'Shahlo Ahmedova'

# %%
muzic3 = {
    'muzic_name': {'Bahrom Nazarov':'olcha gul bodom', 'Ummon':'dengiz', 'Bojalar':'bor'},
    'nashr_sanasi':{'Bahrom Nazarov':2023, 'Ummon':2004, 'Farruh Fazel':2025}
    }

# %%
muzicalar = pd.concat([muzic, DataFrame(muzic3)])
muzicalar
# Out:
#                          muzic_name  nashr_sanasi
# Shoxruxxon                  parizod        2005.0
# G'aybulla Tursunov          quralay        2025.0
# Shahlo Ahmedova              avayla        2017.0
# Bojalar                       anhor        2007.0
# Ismail                 ifori kelsin        2025.0
# Bahrom Nazarov      olcha gul bodom        2023.0
# Ummon                        dengiz        2004.0
# Bojalar                         bor           NaN
# Farruh Fazel                    NaN        2025.0

# %%
muzicalar.index.name = 'ijrochi'
muzicalar
# Out:
#                          muzic_name  nashr_sanasi
# ijrochi
# Shoxruxxon                  parizod        2005.0
# G'aybulla Tursunov          quralay        2025.0
# Shahlo Ahmedova              avayla        2017.0
# Bojalar                       anhor        2007.0
# Ismail                 ifori kelsin        2025.0
# Bahrom Nazarov      olcha gul bodom        2023.0
# Ummon                        dengiz        2004.0
# Bojalar                         bor           NaN
# Farruh Fazel                    NaN        2025.0

# %%
xarita = pd.Index(['Ummon', 'Benom', 'Green71'])
xarita
# Out:
# Index(['Ummon', 'Benom', 'Green71'], dtype='object')

# %%
xarita.isin(muzicalar.index)
# muzicslar nomli indEXdA SHU MALUMOTLAR tRUE AKSINCHA False qilib chiqarib berdi
# Out:
# array([ True, False, False])

# %%
muzicalar.index.difference(xarita)
#farqini topish uchun ishlatdik
# Out:
# Index(['Bahrom Nazarov', 'Bojalar', 'Farruh Fazel', 'G'aybulla Tursunov',
#        'Ismail', 'Shahlo Ahmedova', 'Shoxruxxon'],
#       dtype='object')

# %%
muzicalar.index.union(xarita)
# 2 ta indexda bor malumotlarni chiqarib berdi
# Out:
# Index(['Bahrom Nazarov', 'Benom', 'Bojalar', 'Bojalar', 'Farruh Fazel',
#        'G'aybulla Tursunov', 'Green71', 'Ismail', 'Shahlo Ahmedova',
#        'Shoxruxxon', 'Ummon'],
#       dtype='object')

# %%
muzicalar.index.delete(0)
#index ichidan 0 - elemntni ochirib tashladik
muzicalar
# Out:
#                          muzic_name  nashr_sanasi
# ijrochi
# Shoxruxxon                  parizod        2005.0
# G'aybulla Tursunov          quralay        2025.0
# Shahlo Ahmedova              avayla        2017.0
# Bojalar                       anhor        2007.0
# Ismail                 ifori kelsin        2025.0
# Bahrom Nazarov      olcha gul bodom        2023.0
# Ummon                        dengiz        2004.0
# Bojalar                         bor           NaN
# Farruh Fazel                    NaN        2025.0

# %%
xarita
# Out:
# Index(['Ummon', 'Benom', 'Green71'], dtype='object')

# %%
topmoq = pd.Index(['Shahlo Ahmedova', 'Ismail', 'Jakone'])
topmoq
# Out:
# Index(['Shahlo Ahmedova', 'Ismail', 'Jakone'], dtype='object')

# %%
topmoq.isin(muzicalar.index)
# Out:
# array([ True,  True, False])

# %%
muzicalar.index.intersection(topmoq)
# Out:
# Index(['Shahlo Ahmedova', 'Ismail'], dtype='object')

# %%
muzicalar.index.delete(0)
# Out:
# Index(['G'aybulla Tursunov', 'Shahlo Ahmedova', 'Bojalar', 'Ismail',
#        'Bahrom Nazarov', 'Ummon', 'Bojalar', 'Farruh Fazel'],
#       dtype='object', name='ijrochi')

# %%
muzicalar
# Out:
#                          muzic_name  nashr_sanasi
# ijrochi
# Shoxruxxon                  parizod        2005.0
# G'aybulla Tursunov          quralay        2025.0
# Shahlo Ahmedova              avayla        2017.0
# Bojalar                       anhor        2007.0
# Ismail                 ifori kelsin        2025.0
# Bahrom Nazarov      olcha gul bodom        2023.0
# Ummon                        dengiz        2004.0
# Bojalar                         bor           NaN
# Farruh Fazel                    NaN        2025.0
