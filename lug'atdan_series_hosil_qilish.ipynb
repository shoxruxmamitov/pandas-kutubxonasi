# %% [markdown]
# <a href="https://colab.research.google.com/github/shoxruxmamitov/pandas-kutubxonasi/blob/main/lug'atdan_series_hosil_qilish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
from pandas import Series, DataFrame

# %%
kvv = Series([18, 26, 19, 21, 37, 27], index=['shoxrux', 'javohir', 'muhammad', 'islom', 'doston', 'shaxrior'])
kvv                         # index hosil qilib oldik
# Out:
# shoxrux     18
# javohir     26
# muhammad    19
# islom       21
# doston      37
# shaxrior    27
# dtype: int64

# %% [markdown]
# oddi lugat

# %%
avtasalon1 = {'Malibu': 45000, 'Cobalt':32000, 'Gentra':30000, 'Nexia3':25000, 'Tracker':47000}
avtasalon1 #lugat hosil qilib oldik
# Out:
# {'Malibu': 45000,
#  'Cobalt': 32000,
#  'Gentra': 30000,
#  'Nexia3': 25000,
#  'Tracker': 47000}

# %%
avtasalon=Series(avtasalon1)
avtasalon #oddi lugatni series orqali jadval korinishiga kelitirib oldik
# Out:
# Malibu     45000
# Cobalt     32000
# Gentra     30000
# Nexia3     25000
# Tracker    47000
# dtype: int64

# %% [markdown]
# jadval hosil qilish

# %%
kitob_beti = Series([129, 159, 253, 309, 312, 275], index=['o\'tkan kunlar', 'oq kema', 'besh bolali yigitcha', 'nazar', 'kumush', 'sevgi'])
kitob_beti   #jadval hosil qilib oldik
# Out:
# o'tkan kunlar           129
# oq kema                 159
# besh bolali yigitcha    253
# nazar                   309
# kumush                  312
# sevgi                   275
# dtype: int64

# %%
'Gentra' in avtasalon # jadval ichidan Gentra True bor False ligini tekshirib oldik
# Out:
# True

# %%
'anor' in kitob_beti # bundaham huddi shunaqa qilib true va falseligini tekshirib oldik
# Out:
# False

# %%
avtasalon['Cobalt'] # cobalt indexini lugatini chiqarib oldik
# Out:
# np.int64(32000)

# %%
avtasalon['Nexia3'] # bu ham huddi shunaqa
# Out:
# np.int64(25000)

# %%
kitob_beti['oq kema'] # kitob_beti jadvalidan oq kema indexini lugatini chiqarib oldk
# Out:
# np.int64(159)

# %% [markdown]
# roxat ketma ketligi

# %%
avtasalon1
# Out:
# {'Malibu': 45000,
#  'Cobalt': 32000,
#  'Gentra': 30000,
#  'Nexia3': 25000,
#  'Tracker': 47000}

# %%
models = ['Changan', 'Cobalt', 'Malibu', 'Haval', 'Nexia3', 'Tracker', 'Kia k8', 'Gentra']
      #oddi lugat hosil qilib oldik

# %%
sergeli_avtasalon = Series(avtasalon1, index=models)
sergeli_avtasalon # jadval hosilqildik) sergeli avtasalon ozgaruvchi degan nom berdik
                  # uni Series orqali jadval qildik uning ichiga avtasalon1
                  # dagi index lugatini kochirib olib models ozgarub=vchini
                  # qimatlarini qoshib oldik va berilgan natija
                  # avtasalon1 dagi indexlarni olib models indexlarini qoshiib berdi
                  # avtasalon1 dagi lugatlarni modelsga kochirib oldi
# Out:
# Changan        NaN
# Cobalt     32000.0
# Malibu     45000.0
# Haval          NaN
# Nexia3     25000.0
# Tracker    47000.0
# Kia k8         NaN
# Gentra     30000.0
# dtype: float64
