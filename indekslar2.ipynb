# %% [markdown]
# <a href="https://colab.research.google.com/github/shoxruxmamitov/pandas-kutubxonasi/blob/main/indekslar2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
from pandas import Series, DataFrame

# %%
nikk = {'Nurbek':'nurik12', "Qilichbek":'qilichbek007', "Og'abek":"og'ash", 'Malika':'malika_ladi', 'Alisher':'alish-ajal', 'Shoxrux':'shox07'}
email =  {'Nurbek':'nurbek12@gamil.com', 'Qilichbek':'qilich07@gamil.uz', 'Og\'abek':"og'abek.gamil.ru", 'Malika':'mailka21@.uz', 'Alisher':'alishergamil.uz', 'Shoxrux':'shoxruxmamitov007@gmail.com'}
ochilgan_yil = {'Nurbek': 2007, 'Qilichbek':2009, "Og'abek":2010, 'Malika':2008, 'Alisher':2009, 'Shoxrux':2007}
paswword = {
      'nik' : nikk,
      'emails' : email,
      'akk_yili' : ochilgan_yil
  }
game = pd.DataFrame(paswword)

# %%
game
# Out:
#                     nik                       emails  akk_yili
# Nurbek          nurik12           nurbek12@gamil.com      2007
# Qilichbek  qilichbek007            qilich07@gamil.uz      2009
# Og'abek          og'ash             og'abek.gamil.ru      2010
# Malika      malika_ladi                 mailka21@.uz      2008
# Alisher      alish-ajal              alishergamil.uz      2009
# Shoxrux          shox07  shoxruxmamitov007@gmail.com      2007

# %%
game.index.name = 'Players'

# %%
game
# Out:
#                     nik                       emails  akk_yili
# Players
# Nurbek          nurik12           nurbek12@gamil.com      2007
# Qilichbek  qilichbek007            qilich07@gamil.uz      2009
# Og'abek          og'ash             og'abek.gamil.ru      2010
# Malika      malika_ladi                 mailka21@.uz      2008
# Alisher      alish-ajal              alishergamil.uz      2009
# Shoxrux          shox07  shoxruxmamitov007@gmail.com      2007
