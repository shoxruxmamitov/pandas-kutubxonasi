# %% [markdown]
# <a href="https://colab.research.google.com/github/shoxruxmamitov/pandas-kutubxonasi/blob/main/indexlar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd # pandas kutubxonasini chaqirib olamiz

# %%
import numpy as np # nump kutubxonasini chaqirib olamiz

# %%
from pandas import Series, DataFrame #Series va dataFrame malumot tuzulasini chaqiqirib olamiz

# %%
sotuv = {
    'Mahsulot' : ['Qattiq', 'Sut', 'Kolbasa', 'Bruni', 'Sofia Tort', 'Pepsi'],
    'Narhi': [18000, 25000, 35000, 7000, 75000, 18000],
    'Sotilgan_oyi': ['Dekabr', 'Dekabr', 'Dekabr', 'Dekabr', 'Dekabr', 'Dekabr'],
    'Sotuv_foizi': ['32%', '25%', '21%', '15%', '20%', '40%']
}           # oddi lugat hosil qilib olamiz

# %%
sotuv_foizi=DataFrame(sotuv)
sotuv_foizi # dataframe jadval korinishini hosil qilib olamiz
# Out:
#      Mahsulot  Narhi Sotilgan_oyi Sotuv_foizi
# 0      Qattiq  18000       Dekabr         32%
# 1         Sut  25000       Dekabr         25%
# 2     Kolbasa  35000       Dekabr         21%
# 3       Bruni   7000       Dekabr         15%
# 4  Sofia Tort  75000       Dekabr         20%
# 5       Pepsi  18000       Dekabr         40%

# %%
sotuv_foizi.index = [1, 2, 3, 4, 5, 6]
sotuv_foizi # index larga ozimiz hoxlagandek nom beramiz
# Out:
#      Mahsulot  Narhi Sotilgan_oyi Sotuv_foizi
# 1      Qattiq  18000       Dekabr         32%
# 2         Sut  25000       Dekabr         25%
# 3     Kolbasa  35000       Dekabr         21%
# 4       Bruni   7000       Dekabr         15%
# 5  Sofia Tort  75000       Dekabr         20%
# 6       Pepsi  18000       Dekabr         40%

# %%
sotuv_foizi.index #index chaqirib oldik
# Out:
# Index([1, 2, 3, 4, 5, 6], dtype='int64')

# %%
index = sotuv_foizi.columns #indexni alohida qilib oldik va bu bizga malumotlarga ishlov berishda oson boladi

# %%
index
# Out:
# Index(['Mahsulot', 'Narhi', 'Sotilgan_oyi', 'Sotuv_foizi'], dtype='object')

# %%
'Narhi' in index # Narh malumoti index ichida bor bor emasligni tekshirib oldk borligi uchun TRUE qatardi
# Out:
# True

# %%
'Bo\'lim' in index # bo'lim malumoti index ichida mavjud emaligi uchun False qatardi
# Out:
# False

# %%
'Cola' in sotuv_foizi #colani tekshirdik False berdi
# Out:
# False

# %%
'Sotuv_foizi' in sotuv_foizi #sotuv_foizni tekshirdik TRue qatardi
# Out:
# True

# %%
index # inde malumot turini chaqirib oldik
# Out:
# Index(['Mahsulot', 'Narhi', 'Sotilgan_oyi', 'Sotuv_foizi'], dtype='object')

# %%
index[1] # index ichidan malumotni kesib oldik
# Out:
# 'Narhi'

# %%
index[3] # 3 - malumot turini index ichidan kesib oldik
# Out:
# 'Sotuv_foizi'

# %%
index[1:3] # 1 dan 3 gacha bolgan malumotni kesib oldik
# Out:
# Index(['Narhi', 'Sotilgan_oyi'], dtype='object')
