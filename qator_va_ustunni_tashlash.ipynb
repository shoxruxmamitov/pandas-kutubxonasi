# %% [markdown]
# <a href="https://colab.research.google.com/github/shoxruxmamitov/pandas-kutubxonasi/blob/main/qator_va_ustunni_tashlash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
uzb_aholi = {
    'yil':[2020, 2021, 2022, 2023, 2024, 2025],
    'aholi':[33.9, 35.3, 36.0, 36.8, 37.5, 38.00],
    'fozi':['1.89%', '1.99%', '2.03%', '2.04%', '1.99%', '1.90%'],
    'zichlik':['75 kishi/km*', '78.1 kishi/km*', '79.8 kishi/km*', '81.5 kishi/km*', '83.2 kishi/km*', '84.8 kishi/km*']
} #lugat hosilqilib oldik

# %%
uzbekiston_aholi = pd.DataFrame(uzb_aholi) # lugatni dataset korinishiga kelirib oldik

# %%
uzbekiston_aholi # datasetni chqarib oldik
# Out:
#     yil  aholi   fozi         zichlik
# 0  2020   33.9  1.89%    75 kishi/km*
# 1  2021   35.3  1.99%  78.1 kishi/km*
# 2  2022   36.0  2.03%  79.8 kishi/km*
# 3  2023   36.8  2.04%  81.5 kishi/km*
# 4  2024   37.5  1.99%  83.2 kishi/km*
# 5  2025   38.0  1.90%  84.8 kishi/km*

# %%
uzbekiston_aholi.index = [1, 2, 3, 4, 5, 6]
uzbekiston_aholi # index qatorlarini tartib bn jolashtirdik
# Out:
#     yil  aholi   fozi         zichlik
# 1  2020   33.9  1.89%    75 kishi/km*
# 2  2021   35.3  1.99%  78.1 kishi/km*
# 3  2022   36.0  2.03%  79.8 kishi/km*
# 4  2023   36.8  2.04%  81.5 kishi/km*
# 5  2024   37.5  1.99%  83.2 kishi/km*
# 6  2025   38.0  1.90%  84.8 kishi/km*

# %%
uzbekiston_aholi.index.name = 'qator'
uzbekiston_aholi # index ga nom berib oldik
# Out:
#         yil  aholi   fozi         zichlik
# qator
# 1      2020   33.9  1.89%    75 kishi/km*
# 2      2021   35.3  1.99%  78.1 kishi/km*
# 3      2022   36.0  2.03%  79.8 kishi/km*
# 4      2023   36.8  2.04%  81.5 kishi/km*
# 5      2024   37.5  1.99%  83.2 kishi/km*
# 6      2025   38.0  1.90%  84.8 kishi/km*

# %%
ter = uzbekiston_aholi.drop([2,4])
ter # 2 va 4 chi ustunni dataset dan olib tashladik
# Out:
#         yil  aholi   fozi         zichlik
# qator
# 1      2020   33.9  1.89%    75 kishi/km*
# 3      2022   36.0  2.03%  79.8 kishi/km*
# 5      2024   37.5  1.99%  83.2 kishi/km*
# 6      2025   38.0  1.90%  84.8 kishi/km*

# %%
uzbekiston_aholi.drop('yil', axis=1)
uzbekiston_aholi
# Out:
#         yil  aholi   fozi         zichlik
# qator
# 1      2020   33.9  1.89%    75 kishi/km*
# 2      2021   35.3  1.99%  78.1 kishi/km*
# 3      2022   36.0  2.03%  79.8 kishi/km*
# 4      2023   36.8  2.04%  81.5 kishi/km*
# 5      2024   37.5  1.99%  83.2 kishi/km*
# 6      2025   38.0  1.90%  84.8 kishi/km*

# %%
uzbekiston_aholi.drop('yil',  axis = 'columns')
# Out:
#        aholi   fozi         zichlik
# qator
# 1       33.9  1.89%    75 kishi/km*
# 2       35.3  1.99%  78.1 kishi/km*
# 3       36.0  2.03%  79.8 kishi/km*
# 4       36.8  2.04%  81.5 kishi/km*
# 5       37.5  1.99%  83.2 kishi/km*
# 6       38.0  1.90%  84.8 kishi/km*

# %%
uzbekiston_aholi.drop([3, 5], inplace=True)

# %%
uzbekiston_aholi
# Out:
#         yil  aholi   fozi         zichlik
# qator
# 1      2020   33.9  1.89%    75 kishi/km*
# 2      2021   35.3  1.99%  78.1 kishi/km*
# 4      2023   36.8  2.04%  81.5 kishi/km*
# 6      2025   38.0  1.90%  84.8 kishi/km*
